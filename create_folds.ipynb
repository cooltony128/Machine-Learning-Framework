# %%
import pandas as pd

# %%
from sklearn import model_selection

# %%
df = pd.read_csv('TRAIN_CLEANED.csv')

# %%
df.head()
# Out:
#    age   Private   Self-employed-incorporated   State government  \
# 0   33         1                            0                  0
# 1   63         1                            0                  0
# 2   71         0                            0                  0
# 3   43         0                            0                  0
# 4   57         0                            0                  0
#
#     Self-employed-not incorporated   Not in universe   Without pay  \
# 0                                0                 0             0
# 1                                0                 0             0
# 2                                0                 1             0
# 3                                0                 0             0
# 4                                0                 0             0
#
#     Federal government   Never worked   Local government  ...  \
# 0                    0              0                  0  ...
# 1                    0              0                  0  ...
# 2                    0              0                  0  ...
# 3                    0              0                  1  ...
# 4                    0              0                  1  ...
#
#     Not in universe.12   Yes.3   No.3   2.3   0.3   1.3  weeks worked in year  \
# 0                    1       0      0     1     0     0                    52
# 1                    1       0      0     1     0     0                    52
# 2                    1       0      0     1     0     0                     0
# 3                    1       0      0     1     0     0                    52
# 4                    1       0      0     1     0     0                    52
#
#     94  label  age below fifty
# 0    0      1             True
# 1    0      0            False
# 2    0      0            False
# 3    0      0             True
# 4    0      0            False
#
# [5 rows x 471 columns]

# %%
df['kfold'] = -1

# %%
df = df.sample(frac=1).reset_index(drop=True) #we sample the whole thing

# %%
kf = model_selection.StratifiedKFold(n_splits=5, shuffle=False, random_state=128)

# %%
for fold, (trainindex ,validationindex) in enumerate(kf.split(X=df, y=df.label.values)):
    df.loc[validationindex, 'kfold']=fold

# %%
df.to_csv('TRAIN_CLEANED_FOLDS.csv', index=False)
